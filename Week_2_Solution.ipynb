# %% [markdown]
# <a href="https://colab.research.google.com/github/kalomausman/exercise_submissions/blob/main/Week_2_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arewa Data Science Academy (Week 2 Assignment)
#
# Deep Learning Cohort2.0
#
# Name: Kaloma Usman Majikumna

# %%
import torch
import matplotlib.pyplot as plt


torch.manual_seed(42) # Seed for reproducibility

# The required parameters in the excercise
weight = 0.3
bias = 0.9
num_samples = 100

# Generate data
X = torch.linspace(0, 10, num_samples)
y = weight * X + bias # This the linear regression formula

# Split data into training (80%) and testing (20%)
split = int(0.8 * num_samples)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Plot the data
#plt.figure(figsize=(8, 5))
#plt.scatter(X_train, y_train, label='Training Data', color='blue', alpha=0.6)
plt.scatter(X_test, y_test, label='Testing Data', color='red', alpha=0.6)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Generated Linear Regression Dataset')
plt.legend()
plt.show()

# %%
import torch
import matplotlib.pyplot as plt


torch.manual_seed(42) # Seed for reproducibility

# The required parameters in the excercise
weight = 0.3
bias = 0.9
num_samples = 100

# Generate data
X = torch.linspace(0, 10, num_samples)
y = weight * X + bias # This the linear regression formula

# Split data into training (80%) and testing (20%)
split = int(0.8 * num_samples)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Plot the data
#plt.figure(figsize=(8, 5))
#plt.scatter(X_train, y_train, label='Training Data', color='blue', alpha=0.6)
#plt.scatter(X_test, y_test, label='Testing Data', color='red', alpha=0.6)
#plt.xlabel('X')
#plt.ylabel('y')
#plt.title('Generated Linear Regression Dataset')
#plt.legend()
#plt.show()

# %%
import torch.nn as nn

# Set seed for reproducibility
torch.manual_seed(42)

# Define parameters
weight = 0.3
bias = 0.9
num_samples = 100

# Generate data
X = torch.linspace(0, 10, num_samples)
y = weight * X + bias

# Split data into training (80%) and testing (20%)
split = int(0.8 * num_samples)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Plot the data
#plt.figure(figsize=(8, 5))
#plt.scatter(X_train, y_train, label='Training Data', color='blue', alpha=0.6)
#plt.scatter(X_test, y_test, label='Testing Data', color='red', alpha=0.6)
#plt.xlabel('X')
#plt.ylabel('y')
#plt.title('Generated Linear Regression Dataset')
#plt.legend()
#plt.show()

# Define PyTorch model
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(1, requires_grad=True))
        self.bias = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.weight * x + self.bias

# Create model instance
model = LinearRegressionModel()

# Print model parameters
print("Model state_dict:", model.state_dict())

# Plot the data
#plt.figure(figsize=(8, 5))
#plt.scatter(X_train, y_train, label='Training Data', color='blue', alpha=0.6)
#plt.scatter(X_test, y_test, label='Testing Data', color='red', alpha=0.6)
#plt.xlabel('X')
#plt.ylabel('y')
#plt.title('Generated Linear Regression Dataset')
#plt.legend()
#plt.show()
# Out:
# Model state_dict: OrderedDict([('weight', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
#Compiling everything together.
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# Set seed for reproducibility
torch.manual_seed(42)

# The requested parameters
weight = 0.3
bias = 0.9
num_samples = 100

# Generate data
X = torch.linspace(0, 10, num_samples).unsqueeze(1)  # Add an extra dimension
y = weight * X + bias

# Split data into training (80%) and testing (20%)
split = int(0.8 * num_samples)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Define PyTorch model
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(1, requires_grad=True))
        self.bias = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.weight * x + self.bias #This where the formula is implemented

# Create model instance
model = LinearRegressionModel()

# Define loss function and optimizer
criterion = nn.L1Loss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training loop
num_epochs = 300
for epoch in range(num_epochs):
    # Forward pass
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)

    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Test model every 20 epochs
    if (epoch + 1) % 20 == 0:
        model.eval()
        with torch.no_grad():
            test_preds = model(X_test)
            test_loss = criterion(test_preds, y_test)
        model.train()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')

# Make predictions
model.eval()
with torch.no_grad():
    y_pred_train = model(X_train)
    y_pred_test = model(X_test)

# Plot the data
plt.figure(figsize=(8, 5))
plt.scatter(X_train, y_train, label='Training Data', color='blue', alpha=0.6)
plt.scatter(X_test, y_test, label='Testing Data', color='red', alpha=0.6)
plt.plot(X_train, y_pred_train, label='Model Predictions (Train)', color='green')
plt.plot(X_test, y_pred_test, label='Model Predictions (Test)', color='purple')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Generated Linear Regression Dataset')
plt.legend()
plt.show()

# Save model state
torch.save(model.state_dict(), "linear_regression_model.pth")

# Load model and test predictions
loaded_model = LinearRegressionModel()
loaded_model.load_state_dict(torch.load("linear_regression_model.pth"))
loaded_model.eval()
with torch.no_grad():
    loaded_test_preds = loaded_model(X_test)

# Verify predictions
print("Original model predictions:", y_pred_test[:5].squeeze().tolist())
print("Loaded model predictions:", loaded_test_preds[:5].squeeze().tolist())
# Out:
# Epoch [20/300], Loss: 0.2840, Test Loss: 0.4117
# Epoch [40/300], Loss: 0.2502, Test Loss: 0.3612
# Epoch [60/300], Loss: 0.2163, Test Loss: 0.3107
# Epoch [80/300], Loss: 0.1824, Test Loss: 0.2602
# Epoch [100/300], Loss: 0.1485, Test Loss: 0.2097
# Epoch [120/300], Loss: 0.1147, Test Loss: 0.1594
# Epoch [140/300], Loss: 0.0811, Test Loss: 0.1002
# Epoch [160/300], Loss: 0.0529, Test Loss: 0.1209
# Epoch [180/300], Loss: 0.0902, Test Loss: 0.2628
# Epoch [200/300], Loss: 0.0539, Test Loss: 0.3035
# Epoch [220/300], Loss: 0.0168, Test Loss: 0.3664
# Epoch [240/300], Loss: 0.0554, Test Loss: 0.2683
# Epoch [260/300], Loss: 0.0484, Test Loss: 0.2772
# Epoch [280/300], Loss: 0.0459, Test Loss: 0.2797
# Epoch [300/300], Loss: 0.0456, Test Loss: 0.2799
# Original model predictions: [3.5744705200195312, 3.607900857925415, 3.6413309574127197, 3.6747612953186035, 3.7081916332244873]
# ...
